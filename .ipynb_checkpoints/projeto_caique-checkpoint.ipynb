# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
caminho_dados = '/home/breno/Documentos/projeto_caique'
os.listdir(caminho_dados)
# Out:
# ['dados.xlsx', '.~lock.dados.xlsx#']

# %%
dados = pd.read_excel(caminho_dados + '/dados.xlsx')

# %%
# vou criar um header pra ficar mais facil de ler cada uma das colunas:
header = [
    'Data Medicao',
    'Dir Vento',
    'Evapo Piche',
    'Evapotransp Potencial',
    'Evapotransp Real',
    'Insolacao Total',
    'Nebulosidade',
    'No de dias com prec pluv',
    'Prec Total',
    'Pressao',
    'T max',
    'T media',
    'T min',
    'UR',
    'Vento max',
    'Vento med',
    'Vis med',
    'NaN'
]

# %%
dados_tratado = dados[382:] # so a partir daqui eu tenho dado
dados_tratado.columns = header
dados_tratado = dados_tratado.set_index([dados_tratado['Data Medicao']])
dados_tratado.drop('Data Medicao', axis=1)
dados_tratado['Prec Total'] = pd.to_numeric(dados_tratado['Prec Total']) # teria que fazer isso com todos os que tao c erro....
# Out:
#              Dir Vento Evapo Piche Evapotransp Potencial Evapotransp Real  \
# Data Medicao
# 1961-01-31           5         NaN                   NaN              NaN
# 1961-02-28           5         NaN                   NaN              NaN
# 1961-03-31           5         NaN                   NaN              NaN
# 1961-04-30           5         NaN                   NaN              NaN
# 1961-05-31           5         NaN                   NaN              NaN
# 1961-06-30           9         NaN                   NaN              NaN
# 1961-07-31           9         NaN                   NaN              NaN
# 1961-08-31           5         NaN                   NaN              NaN
# 1961-09-30           5         NaN                   NaN              NaN
# 1961-10-31           5         NaN                   NaN              NaN
# 1961-11-30           5         NaN                   NaN              NaN
# 1961-12-31           5         NaN                   NaN              NaN
# 1962-01-31           5         NaN                   NaN              NaN
# 1962-02-28           5         NaN                   NaN              NaN
# 1962-03-31           5         NaN                   NaN              NaN
# 1962-04-30           9         NaN                   NaN              NaN
# 1962-05-31          18        72.9                   NaN              NaN
# 1962-06-30          23        68.4                   NaN              NaN
# 1962-07-31          23        64.1                   NaN              NaN
# 1962-08-31           5        89.2                   NaN              NaN
# 1962-09-30           5        83.6                   NaN              NaN
# 1962-10-31           5        89.7                   NaN              NaN
# 1962-11-30           5        93.9                   NaN              NaN
# 1962-12-31           5        81.1                   NaN              NaN
# 1963-01-31           5       122.1                   NaN              NaN
# 1963-02-28           5          92                   NaN              NaN
# 1963-03-31           5       112.8                   NaN              NaN
# 1963-04-30          18        75.7                   NaN              NaN
# 1963-05-31           9        83.5                   NaN              NaN
# 1963-06-30          14        59.5                   NaN              NaN
# 1963-07-31           5        67.3                   NaN              NaN
# 1963-08-31           5        84.5                   NaN              NaN
# 1963-09-30           5          96                   NaN              NaN
# 1963-10-31           5       102.2                   NaN              NaN
# 1963-11-30           5        88.1                   NaN              NaN
#
#              Insolacao Total Nebulosidade No de dias com prec pluv Prec Total  \
# Data Medicao
# 1961-01-31               NaN      7706522                       17      154.1
# 1961-02-28               NaN      3595238                        9       21.1
# 1961-03-31               NaN      4494624                       13       63.9
# 1961-04-30               NaN      5433333                       13      112.3
# 1961-05-31               NaN       511828                       15      136.2
# 1961-06-30               NaN      4588889                       15      114.3
# 1961-07-31               NaN      5655914                       17        104
# 1961-08-31               NaN       316129                        3        6.3
# 1963-06-30    1018842222     24.56  21658667  18346667     82725         7
# 1963-07-31    1019246237  24158065  21055484  17316129  81491935         7
# 1963-08-31     101803871  24609677  21544516  17429032  78459677         7
# 1963-09-30    1016997778  25716667     23058  19793333     78175         9
# 1963-10-31    1014775269  27180645  24663226  21935484  78943548         9
# 1963-11-30    1011854444     27.75  25367333  22796667     80.75         9
#
#              Vento med   Vis med  NaN
# Data Medicao
# 1961-01-31     5358696  57419355  NaN
# 1961-02-28      397619        60  NaN
# 1961-03-31     3537634  58387097  NaN
# 1961-04-30     2688889      57.5  NaN
# 1961-05-31     2494624  57741935  NaN
# 1961-06-30     2877778      58.5  NaN
# 1961-07-31     2129032  57419355  NaN
# 1961-08-31     3010753   5983871  NaN
# 1961-09-30     5133333  58666667  NaN
# 1961-10-31     4666667  59193548  NaN
# 1961-11-30     5711111      58.5  NaN
# 1961-12-31     5258065  56612903  NaN
# 1962-01-31     4655914  57419355  NaN
# 1962-02-28     5285714  58214286  NaN
# 1962-03-31           3  59516129  NaN
# 1962-04-30     2933333  59666667  NaN
# 1962-05-31     3215054  57741935  NaN
# 1962-06-30     2755556  58166667  NaN
# 1962-07-31     2666667  58774194  NaN
# 1962-08-31     3752688  59032258  NaN
# 1962-09-30     3911111        58  NaN
# 1962-10-31     4688172  55806452  NaN
# 1962-11-30     4477778  56166667  NaN
# 1962-12-31     4408602  56451613  NaN
# 1963-01-31     4064516   5983871  NaN
# 1963-02-28     3416667  59285714  NaN
# 1963-03-31     2946237   5983871  NaN
# 1963-04-30     2988889  58833333  NaN
# 1963-05-31     2763441  58387097  NaN
# 1963-06-30     2544444  55833333  NaN
# 1963-07-31           3  57419355  NaN
# 1963-08-31     3365591  58709677  NaN
# 1963-09-30     3944444        55  NaN
# 1963-10-31     4774194  53064516  NaN
# 1963-11-30     4155556  58166667  NaN

# %% [markdown]
# # Agora parece ja estar tratadinho

# %%
plt.plot(dados_tratado['Prec Total'])

# %%
from windrose import WindroseAxes
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Create wind speed and direction variables

ws = np.random.random(35) * 6
wd = dados_tratado['Dir Vento']

ax = WindroseAxes.from_ax()

ax.set_xticklabels(['E', 'NE',  'N', 'NW', 'W', 'SW','S', 'SE'])
#ax.set_theta_zero_location('N')

ax.box(wd, ws, bins=np.arange(0, 8, 1))
ax.set_legend()

# %% [markdown]
# # Nova tentativa

# %%
novo_caminho = caminho_dados + '/novo/novo1'

# %%
pd.read_csv(novo_caminho + '/1930.csv',sep=';',decimal=',')
# Out:
#            Data Medicao\tDIRECAO PREDOMINANTE DO VENTO  \
# 0    1930-01-31\tnull\tnull\tnull\tnull\tnull\tnull...
# 1    1930-02-28\tnull\tnull\tnull\tnull\tnull\tnull...
# 2    1930-03-31\tnull\tnull\tnull\tnull\tnull\tnull...
# 3    1930-04-30\tnull\tnull\tnull\tnull\tnull\tnull...
# 4    1930-05-31\tnull\tnull\tnull\tnull\tnull\tnull...
# ..                                                 ...
# 402                                  1963-07-31\t5\t67
# 403                                  1963-08-31\t5\t84
# 404             1963-09-30\t5\t96\tnull\tnull\tnull\t4
# 405                                 1963-10-31\t5\t102
# 406                                  1963-11-30\t5\t88
#
#      MENSAL(° (gr))\tEVAPORACAO DO PICHE  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 402               3\tnull\tnull\tnull\t4
# 403               5\tnull\tnull\tnull\t3
# 404                        488889\t7\t14
# 405               2\tnull\tnull\tnull\t4
# 406               1\tnull\tnull\tnull\t5
#
#      MENSAL(mm)\tEVAPOTRANSPIRACAO POTENCIAL  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 402                           215054\t10\t69
# 403                            860215\t6\t47
# 404                                  5\t1016
# 405                             817204\t2\t9
# 406                          555556\t11\t129
#
#      BH MENSAL(mm)\tEVAPOTRANSPIRACAO REAL  BH MENSAL(mm)\tINSOLACAO TOTAL  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                      NaN                             NaN
# ..                                     ...                             ...
# 402                                9\t1019                      246237\t24
# 403                                3\t1018                       03871\t24
# 404                             997778\t25                      716667\t23
# 405                                5\t1014                      775269\t27
# 406                                3\t1011                      854444\t27
#
#      MENSAL(h)\tNEBULOSIDADE  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 402               158065\t21
# 403               609677\t21
# 404                  058\t19
# 405               180645\t24
# 406                   75\t25
#
#      MEDIA MENSAL(décimos)\tNUMERO DE DIAS COM PRECIP. PLUV  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 402                                         055484\t17
# 403                                         544516\t17
# 404                                         793333\t78
# 405                                         663226\t21
# 406                                         367333\t22
#
#      MENSAL(número)\tPRECIPITACAO TOTAL  MENSAL(mm)\tPRESSAO ATMOSFERICA  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
# ..                                  ...                              ...
# 402                          316129\t81                 491935\t7\t3\t57
# 403                          429032\t78                     459677\t7\t3
# 404                           175\t9\t3                 944444\t55\tnull
# 405                          935484\t78                     943548\t9\t4
# 406                          796667\t80                         75\t9\t4
#
#      MEDIA MENSAL(mB)\tTEMPERATURA MAXIMA MEDIA  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 402                                419355\tnull
# 403                                  365591\t58
# 404                                         NaN
# 405                                  774194\t53
# 406                                  155556\t58
#
#      MENSAL(°C)\tTEMPERATURA MEDIA COMPENSADA  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 402                                       NaN
# 403                              709677\tnull
# 404                                       NaN
# 405                              064516\tnull
# 406                              166667\tnull
#
#       MENSAL(°C)\tTEMPERATURA MINIMA MEDIA  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 402                                    NaN
# 403                                    NaN
# 404                                    NaN
# 405                                    NaN
# 406                                    NaN
#
#       MENSAL(°C)\tUMIDADE RELATIVA DO AR   MEDIA MENSAL(%)\tVENTO  \
# 0                                    NaN                      NaN
# 1                                    NaN                      NaN
# 2                                    NaN                      NaN
# 3                                    NaN                      NaN
# 4                                    NaN                      NaN
# ..                                   ...                      ...
# 402                                  NaN                      NaN
# 403                                  NaN                      NaN
# 404                                  NaN                      NaN
# 405                                  NaN                      NaN
# 406                                  NaN                      NaN
#
#       VELOCIDADE MAXIMA MENSAL(m/s)\tVENTO  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 402                                    NaN
# 403                                    NaN
# 404                                    NaN
# 405                                    NaN
# 406                                    NaN
#
#       VELOCIDADE MEDIA MENSAL(m/s)\tVISIBILIDADE   MEDIA MENSAL(codigo)\t
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
# ..                                           ...                      ...
# 402                                          NaN                      NaN
# 403                                          NaN                      NaN
# 404                                          NaN                      NaN
# 405                                          NaN                      NaN
# 406                                          NaN                      NaN
#
# [407 rows x 17 columns]

# %%
dados30 = pd.read_csv(novo_caminho + '/1930.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-47-09af91b2f0a7> in <module>
# ----> 1 dados30 = pd.read_csv(novo_caminho + '/1930.csv')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2059     def read(self, nrows=None):
#    2060         try:
# -> 2061             data = self._reader.read(nrows)
#    2062         except StopIteration:
#    2063             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 11, saw 17

# %% [markdown]
# # Precisaremos de mais uma tentativa!
